# %% [markdown]
# # Строки и что с ними можно делать
#
# Мы уже знаем о том, как работает конкатенация и умножение строк на числа.

# %%
first_name = input('Введите имя: ')
last_name = input('Введите фамилию: ')

print('Здравствуйте, ' + first_name + ' ' + last_name + '!')

# %%
three = 'три'

print(three * 5 + ' - будет дырка')

# %% [markdown]
# Что еще можно делать со строками?

# %%
line = 'quiddich'

len(line) # определяем длину строки
# Out:
# 8

# %% [markdown]
# ## Методы

# %% [markdown]
# Для строк существует большое количество методов. Метод - это что-то, очень похожее на функцию, но отличается тем, что может применяться только к определенному типу данных.
#
# Например print() работает на любых данных. А вот .upper() на числах не сработает. Метод приводит строку к верхнему регистру. Для чисел он не имеет смысла, потому что у чисел нет регистра.
#
# Обратите внимание на синтаксис: методы, в отличие от функций, пишутся после данных, к которым они будут применены, через точку. Скобки, как и у функций, обязательны, даже если они пустые.

# %%
line.upper()

# %%
'EXPILLIARMUS'.lower()

# %%
doll = 'матрёшка'

doll.replace('ё', 'е')

# %%
kettle = 'скот'

kettle.replace('с', '')

# %%
'уруруруруру'.replace('у', 'а')

# %% [markdown]
# ## Индексы

# %% [markdown]
# Строка - это символы, расположенные в определенном порядке. Значит у каждого символа есть порядковый номер. Такой номер называют **индексом**.
#
# **Счёт в Python начинается с 0.**

# %%
line[0]
# Out:
# 'q'

# %%
'witch'[0]
# Out:
# 'w'

# %%
line[1]
# Out:
# 'u'

# %%
line[8]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-1c9a23c2f23f> in <cell line: 0>()
# ----> 1 line[8]
#
# IndexError: string index out of range

# %%
line[len(line) - 1]
# Out:
# 'h'

# %%
line
# Out:
# 'quiddich'

# %%
line[7]
# Out:
# 'h'

# %%
w = 'goodbye'

# %%
len(w)
# Out:
# 7

# %%
w[len(w) - 1]
# Out:
# 'e'

# %% [markdown]
# Индексы могут быть отрицательными.

# %%
line[-1]
# Out:
# 'h'

# %%
line[-2]
# Out:
# 'c'

# %%
line[-len(line)]
# Out:
# 'q'

# %% [markdown]
# Можно находить индекс нужного символа.

# %%
line.find('i')
# Out:
# 2

# %% [markdown]
# В слове quiddich искомая буква встречается 2 раза. Метод вернул нам только первое вхождение.

# %%
line.rfind('i')
# Out:
# 5

# %% [markdown]
# А .rfind() нашел первую i с конца.

# %% [markdown]
# ## Срезы

# %% [markdown]
# Срезы похожи на индексы, но позволяют делать гораздо больше, чем находить какой-то один символ: мы можем получать куски строки, и не обязательно идущие подряд.
#
# Пишется это так: [`начало`:`конец`]. Разберемся по порядку.
#
# Начало всегда включительно, конец всегда не включительно.

# %%
line
# Out:
# 'quiddich'

# %%
line[2:5]
# Out:
# 'idd'

# %%
line[0:4]
# Out:
# 'quid'

# %%
line[:4] # можно пропустить начало, тогда началом будет начало строки
# Out:
# 'quid'

# %%
line[5:] # можно пропустить конец, тогда концом будет конец строки
# Out:
# 'ich'

# %%
line[:] # можно сделать так, хотя в этом нет никакого смысла
# Out:
# 'quiddich'

# %% [markdown]
# Третьим аргументом срезу можно задать шаг. Например, если шаг 2, то мы получим каждый второй символ строки.
# [`начало`:`конец`:`шаг`]

# %%
nums = '0123456789'

# %%
nums[1:8:2]
# Out:
# '1357'

# %%
nums[::3] # почему важно поставить два двоеточия?
# Out:
# '0369'

# %%
nums[:8:2]
# Out:
# '0246'

# %% [markdown]
# Помним, что индексы могут быть отрицательными? Так вот, аргументы срезов тоже могут.

# %%
nums[-7:-2]
# Out:
# '34567'

# %%
nums[-7:7]
# Out:
# '3456'

# %%
nums[-2:-7] # почему получилась пустая строка?
# Out:
# ''

# %%
nums[8:1:-1]
# Out:
# '8765432'

# %%
nums[1:8:-1]
# Out:
# ''

# %%
nums[::-1]
# Out:
# '9876543210'

# %%
nums[-2::-2]
# Out:
# '86420'

# %% [markdown]
# ### Задание 1
#
# Допишите бота так, чтобы в ответ на любое сообщение он отправлял то же сообщение, но в верхнем регистре.

# %% [markdown]
# ### Задание 2
#
# Допишите бота так, чтобы в ответ на любое сообщение он отправлял два символа: первый и последний из полученного сообщения.

# %% [markdown]
# ### Задание 3
#
# Допишите бота так, чтобы в ответ на любое сообщение он печатал это же сообщение в обратном порядке.
